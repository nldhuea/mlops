# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/1576-mlops-machine-learning/aula-5/casas.csv')

# %%
df.head()
# Out:
#    tamanho   ano  garagem   preco
# 0    159.0  2003        2  208500
# 1    117.0  1976        2  181500
# 2    166.0  2001        2  223500
# 3    160.0  1915        3  140000
# 4    204.0  2000        3  250000

# %%
df = df[['tamanho', 'preco']]

# %%
df.head()
# Out:
#    tamanho   preco
# 0    159.0  208500
# 1    117.0  181500
# 2    166.0  223500
# 3    160.0  140000
# 4    204.0  250000

# %%
X = df[['tamanho']]

# %%
y = df['preco']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       tamanho
# 135     156.0
# 1452    100.0
# 762     144.0
# 932     177.0
# 435     154.0

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
modelo.coef_
# Out:
# array([1084.75077747])

# %%
modelo.intercept_
# Out:
# 27206.968559935078

# %% [markdown]
# #Melhorando o modelo

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/1576-mlops-machine-learning/aula-5/casas.csv')

# %%
X = df.drop('preco', axis=1).values
y = df['preco']

# %%
X[:5]
# Out:
# array([[1.590e+02, 2.003e+03, 2.000e+00],
#        [1.170e+02, 1.976e+03, 2.000e+00],
#        [1.660e+02, 2.001e+03, 2.000e+00],
#        [1.600e+02, 1.915e+03, 3.000e+00],
#        [2.040e+02, 2.000e+03, 3.000e+00]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
modelo.predict([[120, 2001, 2]])
# Out:
# array([191436.53503831])

# %%
import pickle

# %%
with open('modelo.sav', 'wb') as arquivo:
  pickle.dump(modelo, arquivo)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.2.2'
